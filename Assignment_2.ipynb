# %%
import pandas as pd

# %% [markdown]
# Q1

# %%
df=pd.read_csv("content_based_recommendation_dataset.csv")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.head(5)
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# Q2

# %%
df.shape
# Out:
# (1474, 13)

# %%
df.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='object')

# %% [markdown]
# Q3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1474 entries, 0 to 1473
# Data columns (total 13 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Number of clicks on similar products                         1474 non-null   int64
#  1   Number of similar products purchased so far                  1474 non-null   int64
#  2   Average rating given to similar products                     1474 non-null   float64
#  3   Gender                                                       1474 non-null   object
#  4   Median purchasing price (in rupees)                          1474 non-null   int64
#  5   Rating of the product                                        1474 non-null   float64
#  6   Brand of the product                                         1474 non-null   object
# ...

# %% [markdown]
# Q4

# %%
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# Price difference                                               0
# dtype: int64

# %% [markdown]
# Q5

# %%
df.dropna()
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# Q6

# %%
df.duplicated().sum()
# Out:
# np.int64(456)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1018, 13)

# %% [markdown]
# Q7

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %% [markdown]
# Q8

# %%
df['Price of the product'].mean()
# Out:
# np.float64(1334.9214145383105)

# %% [markdown]
# Q9

# %%
df["Median purchasing price (in rupees)"].max()
# Out:
# 19000

# %%
df["Median purchasing price (in rupees)"].min()
# Out:
# 100

# %% [markdown]
# Q10

# %%
df["Brand of the product"].value_counts()#.head(10)
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# ...

# %% [markdown]
# Q11

# %%
df.sort_values(by="Price of the product").head(10)
# Out:
#       Number of clicks on similar products  \
# 752                                     40
# 764                                     39
# 788                                     34
# 1282                                    10
# 1303                                     7
# 591                                     14
# 1328                                     8
# 589                                      5
# 1296                                     9
# 114                                     10
#
#       Number of similar products purchased so far  \
# 752                                            16
# 764                                            15
# 788                                            13
# 1282                                            0
# 1303                                            1
# 591                                             7
# 1328                                            2
# 589                                             2
# ...

# %% [markdown]
# Q12

# %%
df[df["Rating of the product"]>=4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# Q13

# %%
df["Price difference"]= df['Price of the product']-df['Median purchasing price (in rupees)']

# %%
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# Q14

# %%
df.groupby("Gender")['Price of the product'].mean().round()
# Out:
# Gender
# female     784.0
# male      1873.0
# Name: Price of the product, dtype: float64

# %% [markdown]
# Q15

# %%
import matplotlib.pyplot as plt

# %%
myplot=df['Price of the product'].value_counts().head(10)
plt.hist(myplot)
plt.Figure(dpi=300)
plt.show()

# %%
# Conclusion:
# •
# Write 4 to 5 lines explaining:
# •
# Which factor influences recommendations the most?
# •
# What changes did you observe after cleaning the data?
# •
# One interesting pattern you found.

# %% [markdown]
# The data shows the online e commerce analytics.
# The rating influences recommendation most.
# The dublicates are removed so the data is easier to sort.
# i fount that highest no of items sold in summer but winter has double sales amount.

# %%
df.groupby("Season")['Price of the product'].sum()
# Out:
# Season
# monsoon    279770
# spring     137670
# summer     269960
# winter     671550
# Name: Price of the product, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# Season
# summer     409
# winter     344
# spring     157
# monsoon    108
# Name: count, dtype: int64
